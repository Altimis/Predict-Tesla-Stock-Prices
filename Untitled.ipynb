# %%
from Scweet.scweet import scrap

# %%
# scrape tweets of @elonmusk that contain images 'display_type = image' and save them in image directory.
# looks like elon only share memes on Twitter
data = scrap(start_date="2017-01-01", max_date="2020-02-01", from_account = None,interval=1, 
      headless=True, display_type="latest", hashtag="tesla", save_images=False)
# Out:
# Scraping on headless mode.
# looking for tweets between 2017-01-01 and 2017-01-02 00:00:00 ...
# scroll 0
# scroll 1
# looking for tweets between 2017-01-02 00:00:00 and 2017-01-03 00:00:00 ...
# Tweet made at: 2017-01-02T23:59:50.000Z is found.
# Tweet made at: 2017-01-02T23:49:07.000Z is found.
# Tweet made at: 2017-01-02T23:42:12.000Z is found.
# Tweet made at: 2017-01-02T23:40:07.000Z is found.
# Tweet made at: 2017-01-02T23:35:14.000Z is found.
# Tweet made at: 2017-01-02T23:32:10.000Z is found.
# Tweet made at: 2017-01-02T23:32:08.000Z is found.
# Tweet made at: 2017-01-02T23:29:42.000Z is found.
# scroll 0
# Tweet made at: 2017-01-02T23:23:52.000Z is found.
# Tweet made at: 2017-01-02T23:23:02.000Z is found.
# Tweet made at: 2017-01-02T23:20:26.000Z is found.
# Tweet made at: 2017-01-02T23:11:48.000Z is found.
# Tweet made at: 2017-01-02T23:01:48.000Z is found.
# Tweet made at: 2017-01-02T23:00:31.000Z is found.
# Tweet made at: 2017-01-02T22:41:58.000Z is found.
# ...
